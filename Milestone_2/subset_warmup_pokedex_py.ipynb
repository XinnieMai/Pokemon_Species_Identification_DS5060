# %%
# !unzip /content/1-151.zip -d /content/pokemon_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/pokemon_dataset/gen-iv/hgss-back-shiny-female/0111_rhyhorn.png
#   inflating: /content/pokemon_dataset/gen-iv/hgss-back-shiny-female/0112_rhydon.png
#   inflating: /content/pokemon_dataset/gen-iv/hgss-back-shiny-female/0118_goldeen.png
#   inflating: /content/pokemon_dataset/gen-iv/hgss-back-shiny-female/0119_seaking.png
#   inflating: /content/pokemon_dataset/gen-iv/hgss-back-shiny-female/0123_scyther.png
#   inflating: /content/pokemon_dataset/gen-iv/hgss-back-shiny-female/0129_magikarp.png
#   inflating: /content/pokemon_dataset/gen-iv/hgss-back-shiny-female/0130_gyarados.png
#    creating: /content/pokemon_dataset/gen-iv/hgss-female/
#   inflating: /content/pokemon_dataset/gen-iv/hgss-female/0003_venusaur.png
#   inflating: /content/pokemon_dataset/gen-iv/hgss-female/0012_butterfree.png
#   inflating: /content/pokemon_dataset/gen-iv/hgss-female/0019_rattata.png
# ...

# %%
# !python pokemon_classifier.py --data_dir /content/pokemon_dataset
# Out:
#   Device: cuda
#
#   PokemonSpriteDataset loaded:
#     Root:       /content/pokemon_dataset
#     Images:     12,996
#     Species:    155
#     Per species: min=1, median=81, max=117, mean=83.8
#
# ...
#   DATASET ANALYSIS & VERIFICATION
# ...
#   Total images:          12,996
#   Number of species:     155
#   Images per species:    min=1, median=81, max=117
#   Long-tail: 3 species <5 imgs, 4 <10 imgs
# ...
#
#   PokemonSpriteDataset loaded:
#     Root:       /content/pokemon_dataset
#     Images:     12,996
#     Species:    155
#     Per species: min=1, median=81, max=117, mean=83.8
#
#   Data Split (stratified, with rare-species handling):
#     Train: 9,097 images (70.0%)
#     Val:   1,950 images (15.0%)
#     Test:  1,949 images (15.0%)
#     Note:  2 species with 1 image (train only)
#            1 species with 2 images (train+val only)
#   Saved: ./results/long_tail_distribution.png
#
# ...
#   EXPERIMENT: ResNet-50 (Pretrained)
# ...
#   Building resnet50 (pretrained=True, classes=155)
# ...

# %%
from IPython.display import Image
Image(filename='./results/training_curves.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1004/2670451438.py in <cell line: 0>()
#       1 from IPython.display import Image
# ----> 2 Image(filename='./results/training_curves.png')
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
from IPython.display import Image
Image(filename='./results/backbone_comparison.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1004/145416145.py in <cell line: 0>()
#       1 from IPython.display import Image
# ----> 2 Image(filename='./results/backbone_comparison.png')
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
from IPython.display import Image
Image(filename='./results/ablation_summary.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1004/1497840675.py in <cell line: 0>()
#       1 from IPython.display import Image
# ----> 2 Image(filename='./results/ablation_summary.png')
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
from IPython.display import Image
Image(filename='./results/confusion_matrix_top20.png')
